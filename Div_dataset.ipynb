# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanOspinaECI/IABO_CAR/blob/main/Div_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Clonación del repositorio**
# Clonar repositorio para obtener datos y separarlos para utilizarlos como entrenamiento y test

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import xlrd
# !git clone https://github.com/JuanOspinaECI/IBAO_CAR.git
# Out:
# fatal: destination path 'IBAO_CAR' already exists and is not an empty directory.

# %%
wb=xlrd.open_workbook("/content/IBAO_CAR/Varianzas_caracteristicas/caracteristicas_JC.xlsx")
sheet = wb.sheet_by_index(0)
axx=sheet.col_values(1,start_rowx=1)
ayy=sheet.col_values(2,start_rowx=1)
azz=sheet.col_values(3,start_rowx=1)
abb=sheet.col_values(4,start_rowx=1)
acc=sheet.col_values(5,start_rowx=1)
add=sheet.col_values(6,start_rowx=1)
clases=np.array(sheet.col_values(7,start_rowx=1))
plt.plot(axx)
plt.figure()
plt.plot(ayy)
plt.figure()
plt.plot(azz)
plt.figure()
plt.plot(abb)
plt.figure()
plt.plot(acc)
plt.figure()
plt.plot(add)

# %%
from sklearn.model_selection import train_test_split
X=np.array([axx,ayy,azz,abb,acc,add])
X=X.transpose()
plt.plot(X)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,clases,test_size=0.3)
plt.plot(X_train)
plt.figure()
plt.plot(X_test)

# %%
print(y_test)
# Out:
# [4. 0. 1. ... 3. 2. 3.]
